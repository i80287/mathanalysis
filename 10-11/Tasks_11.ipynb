# %%
import sympy
from sympy import S, Symbol, symbols, Function, integrate, diff, Curve, plot, plot_parametric, latex, solveset, Interval
from sympy import sin as Sin
from sympy import cos as Cos
from sympy import pi as Pi
from IPython.core.display import Latex
# %matplotlib inline

# %% [markdown]
# ## Занятие 11
# ## Математический анализ
# ## Применение интегралов для вычисления площади фигуры и длины дуги
#
# ### Задание 1
# Вычислить площадь фигуры, ограниченной графиками функций $f = 2 + x^2$ и  $g = 2 - x^3$. Построить графики, найти точки пересечения, затем вычислить соответствующие интегралы.

# %%
x = Symbol('x')
f = x*x + 2
g = -x*x*x + 2

p = plot(ylabel='y', xlabel='x', size=(10, 10), show=False, legend=True)
p.append(plot(f, (x, -1.5, 1), line_color='g', label=f"$f(x) = {latex(f)}$", show=False)[0])
p.append(plot(g, (x, -1.5, 1), line_color='r', label=f"$g(x) = {latex(g)}$", show=False)[0])
p.show()

roots = solveset(f - g, x)
display(Latex(fr"\text{{Точки пересечения: }} {latex(roots)}"))
points = (min(roots), max(roots))
interval = Interval(*points)
f_I = f.integrate((x, *points))
display(Latex(fr"\text{{Интеграл f(x) на }}{latex(interval)}: {latex(f_I)}"))
g_I = g.integrate((x, *points))
display(Latex(fr"\text{{Интеграл g(x) на }}{latex(interval)}: {latex(g_I)}"))
display(Latex(fr"\text{{Площадь фигуры}}: {latex(sympy.Abs(f_I - g_I))}"))
# Out:
# \text{Точки пересечения: } \left\{-1, 0\right\}
# \text{Интеграл f(x) на }\left[-1, 0\right]: \frac{7}{3}
# \text{Интеграл g(x) на }\left[-1, 0\right]: \frac{9}{4}
# \text{Площадь фигуры}: \frac{1}{12}

# %% [markdown]
# ### Задача 2.
# Вычислить площадь фигуры, ограниченной графиком функции $x = \cos^3(t)$, $y = \sin^3(t)$, $0 \le t \le 2\pi$.

# %%
from sympy.abc import t
phi = Cos(t)**3
psi = Sin(t)**3
integral = integrate(psi*(phi.diff(t)), (t, 0, 2*Pi))
sympy.Abs(integral)
# Out:
# 3*pi/8

# %% [markdown]
# ### Задача 3.
# Вычислить площадь фигуры, ограниченной графиком функции $r = \cos(2\phi)$, $-\frac{\pi}{4} \le \phi \le \frac{\pi}{4}$.

# %%
phi = Symbol('f')
r = Cos(2*phi)
integral = S(1)/2*integrate(r*r, (phi, -Pi/4, Pi/4))
sympy.Abs(integral)
# Out:
# pi/8

# %% [markdown]
# ### Задача 4.
# Вычислить длину кривой, заданной уравнением $y^2 = x^3$ при $x$ от 1 до 3.

# %%
x = Symbol('x', positive=True)
y = x**(S(3)*S.Half)
func = sympy.sqrt(1 + (y.diff(x))**2)
length = integrate(func, (x, 1, 3))
length.simplify()
# Out:
# -13*sqrt(13)/27 + 31*sqrt(31)/27

# %% [markdown]
# ### Задача 5.
# Вычислить длину кривой, заданной параметрически $x = \frac{3}{2}\cos^3 t $, $y = 3\sin^3 t$.

# %%
from sympy import plot_parametric
from sympy.calculus import periodicity

t = Symbol('t', positive=True)

phi = (S(1.5)*Cos(t)**3)
psi = (S(3)*Sin(t)**3)
func = (phi.diff(t)**2 + psi.diff(t)**2)**S.Half

display(Latex(fr"\text{{Periodicity }} \phi(x) = {latex(periodicity(phi, t))}"))
display(Latex(fr"\text{{Periodicity }} \psi(x) = {latex(periodicity(psi, t))}"))
display(Latex(fr"\text{{Periodicity integrated function = }} {latex(periodicity(func, t))}"))
plot_parametric((phi, psi), (t, 0, 2*Pi))

length = integrate(func.simplify(), (t, 0, 2*Pi))
display(length)
# Out:
# \text{Periodicity } \phi(x) = 2 \pi
# \text{Periodicity } \psi(x) = 2 \pi
# \text{Periodicity integrated function = } 2 \pi
# 7.00000000000000

# %% [markdown]
# ### Задача 6.
# Вычислить длину кривой, заданной в полярных координатах
# $r = \phi$, $\phi$ от 0 до $2\pi$. Результат вычислить приближенно до 3 знаков после запятой.

# %%
phi = S('phi')
r = phi
length = ((r**2 + r.diff(phi)**2)**S.Half).integrate((phi, 0, 2*Pi))
display(Latex(fr"\text{{Length = }}{latex(length)} \approx {latex(round(length, 3))}"))
# Out:
# \text{Length = }\frac{\operatorname{asinh}{\left(2 \pi \right)}}{2} + \pi \sqrt{1 + 4 \pi^{2}} \approx 21.256

# %% [markdown]
# ### Индивидуальное задание
# Вычислить площадь фигуры, ограниченной графиками функций $f = 2\sin(x)$ и  $g = \cos(2x)$ на интервале  $[0, \pi]$. Построить графики, найти точки пересечения (выделить корни на интервале с помощью intersect и Interval), затем вычислить соответствующие интегралы.

# %% [markdown]
# ## Вариант 50
# $ f(x) = cos (3x) $
#
# $ g(x) = 4 cos (x) $
#
# на интервале [0; 2π]

# %%
from sympy.solvers.ode.systems import FiniteSet
from sympy.series.sequences import Intersection

x = Symbol('x', positive=True, domain=S.Reals)
f = Cos(3*x)
g = 4*Cos(x)

p = plot(ylabel='y', xlabel='x', size=(10, 10), show=False, legend=True)
p.append(plot(f, (x, 0, 2*Pi), line_color='g', label=f"$f(x) = {latex(f)}$", show=False)[0])
p.append(plot(g, (x, 0, 2*Pi), line_color='r', label=f"$g(x) = {latex(g)}$", show=False)[0])

interval = Interval(0, 2*Pi)
roots = Intersection(solveset(f - g, x), interval)

display(Latex(fr"\text{{Точки пересечения f(x) и g(x): }}{latex(roots)}"))
points = FiniteSet(interval.left, *roots, interval.right)
display(Latex(fr"\text{{Границы интегрирования: }}{latex(points)}"))

total_area = S(0)
points_list = sorted(points)
for left_border, right_border in zip(points_list, points_list[1:]):
    f_I = f.integrate((x, left_border, right_border))
    g_I = g.integrate((x, left_border, right_border))
    partially_area = sympy.Abs(f_I - g_I)
    
    sub_interval = Interval(left_border, right_border)
    display(Latex(fr"\text{{Интеграл f(x) на }}{latex(sub_interval)}: {latex(f_I)}"))
    display(Latex(fr"\text{{Интеграл g(x) на }}{latex(sub_interval)}: {latex(g_I)}"))
    display(Latex(fr"\text{{Площадь фигуры на }}{latex(sub_interval)}: {latex(partially_area)}"))
    
    total_area += partially_area

display(Latex(fr"\text{{Площадь фигуры на }}{latex(interval)}: {latex(total_area)}"))

p.show()
# Out:
# \text{Точки пересечения f(x) и g(x): }\left\{\frac{\pi}{2}, \frac{3 \pi}{2}\right\}
# \text{Границы интегрирования: }\left\{0, \frac{\pi}{2}, \frac{3 \pi}{2}, 2 \pi\right\}
# \text{Интеграл f(x) на }\left[0, \frac{\pi}{2}\right]: - \frac{1}{3}
# \text{Интеграл g(x) на }\left[0, \frac{\pi}{2}\right]: 4
# \text{Площадь фигуры на }\left[0, \frac{\pi}{2}\right]: \frac{13}{3}
# \text{Интеграл f(x) на }\left[\frac{\pi}{2}, \frac{3 \pi}{2}\right]: \frac{2}{3}
# \text{Интеграл g(x) на }\left[\frac{\pi}{2}, \frac{3 \pi}{2}\right]: -8
# \text{Площадь фигуры на }\left[\frac{\pi}{2}, \frac{3 \pi}{2}\right]: \frac{26}{3}
# \text{Интеграл f(x) на }\left[\frac{3 \pi}{2}, 2 \pi\right]: - \frac{1}{3}
# \text{Интеграл g(x) на }\left[\frac{3 \pi}{2}, 2 \pi\right]: 4
# \text{Площадь фигуры на }\left[\frac{3 \pi}{2}, 2 \pi\right]: \frac{13}{3}
# \text{Площадь фигуры на }\left[0, 2 \pi\right]: \frac{52}{3}
